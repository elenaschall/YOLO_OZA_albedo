# %%
from ultralytics.data.utils import visualize_image_annotations

# %%
label_map = {  # Define the label map with all annotated class labels.
    0: "bmabz",
    1: "d",
    2: "bp",
}

# %%
# Visualize
visualize_image_annotations(
    "/albedo/work/projects/p_OZA_AI/train_test/images/ballenyislands2015_2015-02-04T03-00-00_000_54.5.png",  # Input image path.
    "/albedo/work/projects/p_OZA_AI/train_test/labels/ballenyislands2015_2015-02-04T03-00-00_000_54.5.txt",  # Annotation file path for the image.
    label_map,
)
